# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# NBA Data Files
games = "Resources/games.csv"
games_details = "Resources/games_details.csv"
players = "Resources/players.csv"
ranking = "Resources/ranking.csv"
teams = "Resources/teams.csv"

# %%
# create a function to scan for multiple dtypes in each column
def find_mult_datatypes_in_cols(dataframe):
    for col in dataframe:
        unique_types = dataframe[col].apply(type).unique()
        if len(unique_types) > 1:
            print(col, unique_types)

# %%
# Read the data from games dataset
games_df = pd.read_csv(games)
print(games_df.shape)
pd.set_option('display.max_columns',50)
games_df.head()
# Out:
# (26651, 21)
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0    2022    1610612740     126.0        0.484        0.926         0.382
# 1    2022    1610612762     120.0        0.488        0.952         0.457
# 2    2022    1610612739     114.0        0.482        0.786         0.313
# 3    2022    1610612755     113.0        0.441        0.909         0.297
# 4    2022    1610612737     108.0        0.429        1.000         0.378
#
# ...

# %%
# Read the data from games_details dataset
games_details_df = pd.read_csv(games_details)
print(games_details_df.shape)
display(games_details_df)
# Out:
# C:\Users\tyson\AppData\Local\Temp\ipykernel_13936\2785769889.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_details_df = pd.read_csv(games_details)
# (668628, 29)
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0       22200477  1610612759               SAS  San Antonio    1629641
# 1       22200477  1610612759               SAS  San Antonio    1631110
# 2       22200477  1610612759               SAS  San Antonio    1627751
# 3       22200477  1610612759               SAS  San Antonio    1630170
# 4       22200477  1610612759               SAS  San Antonio    1630200
# ...          ...         ...               ...          ...        ...
# 668623  11200005  1610612743               DEN       Denver     202706
# 668624  11200005  1610612743               DEN       Denver     202702
# 668625  11200005  1610612743               DEN       Denver     201585
# ...

# %%
# Find the multiple datatypes in each column of the df
find_mult_datatypes_in_cols(games_details_df)
# Out:
# NICKNAME [<class 'str'> <class 'float'>]
# START_POSITION [<class 'str'> <class 'float'>]
# COMMENT [<class 'float'> <class 'str'>]
# MIN [<class 'str'> <class 'float'>]

# %%
# Set one dtype for the columns with multiple dtypes
games_details_df['NICKNAME'] = games_details_df['NICKNAME'].astype(str)
games_details_df['START_POSITION'] = games_details_df['START_POSITION'].astype(str)
games_details_df['COMMENT'] = games_details_df['COMMENT'].astype(str)

# Function to convert values in 'MIN' column to float
def clean_and_convert_to_float(x):
    
    if isinstance(x, str):
        try:
            games_details_df['MIN'] = games_details_df['MIN'].astype(str)
            return float(numeric_part) / 100.0
        except (ValueError, TypeError):
            return pd.NaT
    elif isinstance(x, (float)):
        return float(x)  # Convert integers to float
    else:
        return pd.NaT

# Apply the function to 'MIN' column
games_details_df['MIN'] = games_details_df['MIN'].apply(clean_and_convert_to_float)

# Print and display the updated df
print(games_details_df.shape)
display(games_details_df)
# Out:
# (668628, 29)
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0       22200477  1610612759               SAS  San Antonio    1629641
# 1       22200477  1610612759               SAS  San Antonio    1631110
# 2       22200477  1610612759               SAS  San Antonio    1627751
# 3       22200477  1610612759               SAS  San Antonio    1630170
# 4       22200477  1610612759               SAS  San Antonio    1630200
# ...          ...         ...               ...          ...        ...
# 668623  11200005  1610612743               DEN       Denver     202706
# 668624  11200005  1610612743               DEN       Denver     202702
# 668625  11200005  1610612743               DEN       Denver     201585
# 668626  11200005  1610612743               DEN       Denver     202389
# 668627  11200005  1610612743               DEN       Denver     201951
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  FGM   FGA  \
# ...

# %%
#aggregation test
games_details_df['MIN'] = games_details_df['MIN'].apply(lambda x: pd.to_numeric(x, errors = 'ignore'))
display(games_details_df)
games_details_df.dtypes
find_mult_datatypes_in_cols(games_details_df)
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0       22200477  1610612759               SAS  San Antonio    1629641
# 1       22200477  1610612759               SAS  San Antonio    1631110
# 2       22200477  1610612759               SAS  San Antonio    1627751
# 3       22200477  1610612759               SAS  San Antonio    1630170
# 4       22200477  1610612759               SAS  San Antonio    1630200
# ...          ...         ...               ...          ...        ...
# 668623  11200005  1610612743               DEN       Denver     202706
# 668624  11200005  1610612743               DEN       Denver     202702
# 668625  11200005  1610612743               DEN       Denver     201585
# 668626  11200005  1610612743               DEN       Denver     202389
# 668627  11200005  1610612743               DEN       Denver     201951
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT     MIN  FGM   FGA  \
# ...

# %%
find_mult_datatypes_in_cols(games_details_df)

# %%
# Read the data from players dataset
players_df = pd.read_csv(players)
print(players_df.shape)
players_df.head()
# Out:
# (7228, 4)
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
#Scan for multiple datatypes in each column of the players_df and convert to a single dtype.
find_mult_datatypes_in_cols(players_df)

# %%
# Read the data from ranking dataset
ranking_df = pd.read_csv(ranking)
print(ranking_df.shape)
ranking_df.head()
# Out:
# (210342, 13)
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0      22022    2022-12-22       West       Denver  30
# 1  1610612763          0      22022    2022-12-22       West      Memphis  30
# 2  1610612740          0      22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0      22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0      22022    2022-12-22       West  LA Clippers  33
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN

# %%
#Scan for multiple datatypes in each column of the df and convert to a single dtype.
find_mult_datatypes_in_cols(ranking_df)

# %%
# Read the data from teams dataset
teams_df = pd.read_csv(teams)
print(teams_df.shape)
teams_df.head()
# Out:
# (30, 14)
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
#Scan for multiple datatypes in each column of the df and convert to a single dtype.
find_mult_datatypes_in_cols(teams_df )

# %%
# Create a new dataframe and merge both game datasets
game_data_merge_df = pd.merge(games_details_df, games_df, on='GAME_ID')
print(game_data_merge_df.shape)
pd.set_option('display.max_columns',50)
display(game_data_merge_df)
# Out:
# (669560, 49)
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0       22200477  1610612759               SAS  San Antonio    1629641
# 1       22200477  1610612759               SAS  San Antonio    1631110
# 2       22200477  1610612759               SAS  San Antonio    1627751
# 3       22200477  1610612759               SAS  San Antonio    1630170
# 4       22200477  1610612759               SAS  San Antonio    1630200
# ...          ...         ...               ...          ...        ...
# 669555  11200005  1610612743               DEN       Denver     202706
# 669556  11200005  1610612743               DEN       Denver     202702
# 669557  11200005  1610612743               DEN       Denver     201585
# 669558  11200005  1610612743               DEN       Denver     202389
# 669559  11200005  1610612743               DEN       Denver     201951
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  FGM   FGA  \
# ...

# %%
# Create a new dataframe and merge the team and rankings data sets
team_and_rankings_df = pd.merge(teams_df, ranking_df, on='TEAM_ID')
print(team_and_rankings_df.shape)
pd.set_option('display.max_columns',50)
display(team_and_rankings_df)
# Out:
# (210342, 26)
#         LEAGUE_ID_x     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION  NICKNAME  \
# 0                 0  1610612737      1949      2019          ATL     Hawks
# 1                 0  1610612737      1949      2019          ATL     Hawks
# 2                 0  1610612737      1949      2019          ATL     Hawks
# 3                 0  1610612737      1949      2019          ATL     Hawks
# 4                 0  1610612737      1949      2019          ATL     Hawks
# ...             ...         ...       ...       ...          ...       ...
# 210337            0  1610612744      1946      2019          GSW  Warriors
# 210338            0  1610612744      1946      2019          GSW  Warriors
# 210339            0  1610612744      1946      2019          GSW  Warriors
# 210340            0  1610612744      1946      2019          GSW  Warriors
# 210341            0  1610612744      1946      2019          GSW  Warriors
#
# ...
